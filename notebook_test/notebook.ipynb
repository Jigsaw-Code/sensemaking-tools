# %%
# Clone repo if running in a colab environment
import sys
if 'google.colab' in sys.modules:
  print('running in colab, cloning repo')
  # remove sensemaking-tools in case it already exists
  # !rm -rf sensemaking-tools
  # clone only the desired branch - TODO: replace this with main
  # !git clone --branch dborkan-notebook-test-2 --single-branch https://github.com/Jigsaw-Code/sensemaking-tools
  # Add directory of this ipynb for easy library loading
  sys.path.insert(0,'/content/sensemaking-tools/notebook_test')  # Install python requirements, TODO: switch requirements.txt file
  # !pip3 install -r sensemaking-tools/requirements-dev.txt

# %%
import my_library

# %%
my_library.my_function()
# Out:
# Hello from my_function
